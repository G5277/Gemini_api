# %% [markdown]
# <a href="https://colab.research.google.com/github/G5277/Gemini_api/blob/main/Img_captioning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q --upgrade google-generativeai langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 345.6 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.8/384.8 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 8.7 MB/s eta 0:00:00

# %%
from IPython.display import display
from IPython.display import Markdown
import textwrap

def to_markdown(text):
  text = text.replace('•','*')
  return Markdown(textwrap.indent(text, '>', predicate = lambda _:True))

# %%
import google.generativeai as genai
from google.colab import userdata

import os
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key  = GOOGLE_API_KEY)

# %%
import PIL.Image

img = PIL.Image.open('/content/img.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x1030>

# %%
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash",google_api_key=GOOGLE_API_KEY)

message = input("How can I help you?")
# example
message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": message,
        },
        {"type": "image_url", "image_url": "/content/img.jpg"},
    ]
)
result = llm.invoke([message])

to_markdown(result.content)
# Out:
# How can I help you?Give a poetic description of the image
# >A city of dreams, where the sun sets in hues of orange and pink, casting a warm glow on the cityscape.
# >The Gateway of India, a majestic archway, stands proud, a testament to the city's rich history.
# >A bridge, like a web of threads, stretches across the horizon, connecting the past and present.
# >People stroll along the bustling streets, their lives interwoven with the rhythm of the city.
# >Mumbai, a city of contrasts, where the old and the new coexist in harmony.
